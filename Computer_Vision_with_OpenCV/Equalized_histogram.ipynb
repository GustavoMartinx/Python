# %% [markdown]
# ## Histogram Equalization
# The purpose of histogram equalization is to modify the tonality of the pixels in the image in order to redistribute the histogram precisely because of the possible bad scattering of the levels, both exposure and contrast. Therefore, a sharper image is obtained containing pixels ranging only from 0 to 255.
#
# ##### Library Importing

# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# ##### Image Reading
# The `imread()` function has a second argument that specifies how the image should be read. They can be:
#
# * `cv.imread_color`: Reads the image as colorized
# * `cv.imread_grayscale`: Reads the image in gray scale;
# * `cv.imread_unchanged`: Reads the image including the alpha channel.
#
# One can simply pass these arguments with the integers `1`, `0` and `-1` respectively.

# %%
img = cv.imread("./Resources/Img/einstein.jpg", 0)

# %% [markdown]
# ##### Equalize Histogram Function
#
# `equalizeHist(img)` <br>
# * Input: <br>
#     1.	`img`: Image represented as matrix. <br><br>
# * Saída: New image with equalized histogram.

# %%
imgEqualized = cv.equalizeHist(img)

# %% [markdown]
# ##### Gray Scale Image Plot - Original and Equalized

# %%
fig = plt.figure(figsize=(9,7))

ax1 = fig.add_subplot(121)
plt.imshow(img, cmap=plt.cm.gray) # cmap=plt.cm.gray to make image into gray scale

ax2 = fig.add_subplot(122)
plt.imshow(imgEqualized, cmap=plt.cm.gray)
plt.show()

# %%
fig = plt.figure(figsize=(20,5))

ax1 = fig.add_subplot(121)
plt.hist(img.ravel(), 256, [0, 255])

ax2 = fig.add_subplot(122)
plt.hist(imgEqualized.ravel(), 256, [0, 255])
plt.show()

# %%
## Colorize Image Plot - Original and Equalized
# Image Reading
colorImg = cv.imread("./Resources/Img/dark_city.png", 1)

# Channel Spliting
blue, green, red = cv.split(colorImg)

# Equalized Colorize Image Ploting
colorFig = plt.figure(figsize=(20,5))

#-----------antigo *** NAO É ASSIM. TEM QUE EQUALIZAR TODOS OS CANAIS DE COR
# Equalizing the colorize image
#colorImgEqualized = cv.equalizeHist(colorImg)
#----------
# Equalizing the colorize image
blueEqualized = cv.equalizeHist(blue)
redEqualized = cv.equalizeHist(red)
greenEqualized = cv.equalizeHist(green)

# Colorize Image Ploting
ax10 = fig.add_subplot(121)
plt.imshow(colorImg)

# Equalized Colorize Image Ploting
ax20 = fig.add_subplot(122)
plt.imshow(blueEqualized, redEqualized, greenEqualized)













# Equalized Colorize Image Ploting
colorFig = plt.figure(figsize=(20,5))



# Plottinh the Histogram of each Color Channel
ax1_color = colorFig.add_subplot(131)
ax1_color.hist(blue.ravel(), 256, [0,256])
plt.title("Colorize Histogram Channel Blue")

ax2_color = colorFig.add_subplot(132)
ax2_color.hist(green.ravel(), 256, [0,256])
plt.title("Colorize Histogram Channel Green")

ax3_color = colorFig.add_subplot(133)
ax3_color.hist(red.ravel(), 256, [0,256])
plt.title("Colorize Histogram Channel Red")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4972\3985013731.py in <module>
#      23 # Equalized Colorize Image Ploting
#      24 ax20 = fig.add_subplot(122)
# ---> 25 plt.imshow(blueEqualized, redEqualized, greenEqualized)
#      26
#      27
#
# c:\Users\Usuario\anaconda3\lib\site-packages\matplotlib\_api\deprecation.py in wrapper(*args, **kwargs)
#     457                 "parameter will become keyword-only %(removal)s.",
#     458                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 459         return func(*args, **kwargs)
#     460
#     461     # Don't modify *func*'s signature, as boilerplate.py needs it.
#
# c:\Users\Usuario\anaconda3\lib\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    2650         interpolation_stage=None, filternorm=True, filterrad=4.0,
#    2651         resample=None, url=None, data=None, **kwargs):
# -> 2652     __ret = gca().imshow(
#    2653         X, cmap=cmap, norm=norm, aspect=aspect,
#    2654         interpolation=interpolation, alpha=alpha, vmin=vmin,
#
# c:\Users\Usuario\anaconda3\lib\site-packages\matplotlib\_api\deprecation.py in wrapper(*args, **kwargs)
#     457                 "parameter will become keyword-only %(removal)s.",
#     458                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 459         return func(*args, **kwargs)
#     460
#     461     # Don't modify *func*'s signature, as boilerplate.py needs it.
#
# c:\Users\Usuario\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1410     def inner(ax, *args, data=None, **kwargs):
#    1411         if data is None:
# -> 1412             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1413
#    1414         bound = new_sig.bind(ax, *args, **kwargs)
#
# c:\Users\Usuario\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, **kwargs)
#    5473             aspect = rcParams['image.aspect']
#    5474         self.set_aspect(aspect)
# -> 5475         im = mimage.AxesImage(self, cmap, norm, interpolation,
#    5476                               origin, extent, filternorm=filternorm,
#    5477                               filterrad=filterrad, resample=resample,
#
# c:\Users\Usuario\anaconda3\lib\site-packages\matplotlib\image.py in __init__(self, ax, cmap, norm, interpolation, origin, extent, filternorm, filterrad, resample, interpolation_stage, **kwargs)
#     927         self._extent = extent
#     928
# --> 929         super().__init__(
#     930             ax,
#     931             cmap=cmap,
#
# c:\Users\Usuario\anaconda3\lib\site-packages\matplotlib\image.py in __init__(self, ax, cmap, norm, interpolation, origin, filternorm, filterrad, resample, interpolation_stage, **kwargs)
#     244                  ):
#     245         martist.Artist.__init__(self)
# --> 246         cm.ScalarMappable.__init__(self, norm, cmap)
#     247         if origin is None:
#     248             origin = mpl.rcParams['image.origin']
#
# c:\Users\Usuario\anaconda3\lib\site-packages\matplotlib\cm.py in __init__(self, norm, cmap)
#     355         self._A = None
#     356         self._norm = None  # So that the setter knows we're initializing.
# --> 357         self.set_norm(norm)  # The Normalize instance of this ScalarMappable.
#     358         self.cmap = None  # So that the setter knows we're initializing.
#     359         self.set_cmap(cmap)  # The Colormap instance of this ScalarMappable.
#
# c:\Users\Usuario\anaconda3\lib\site-packages\matplotlib\cm.py in set_norm(self, norm)
#     587         on the colorbar to default.
#     588         """
# --> 589         self.norm = norm
#     590
#     591     def autoscale(self):
#
# c:\Users\Usuario\anaconda3\lib\site-packages\matplotlib\cm.py in norm(self, norm)
#     555     @norm.setter
#     556     def norm(self, norm):
# --> 557         _api.check_isinstance((colors.Normalize, None), norm=norm)
#     558         if norm is None:
#     559             norm = colors.Normalize()
#
# c:\Users\Usuario\anaconda3\lib\site-packages\matplotlib\_api\__init__.py in check_isinstance(_types, **kwargs)
#      91                 names.remove("None")
#      92                 names.append("None")
# ---> 93             raise TypeError(
#      94                 "{!r} must be an instance of {}, not a {}".format(
#      95                     k,
#
# TypeError: 'norm' must be an instance of matplotlib.colors.Normalize or None, not a numpy.ndarray
